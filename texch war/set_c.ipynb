# %%
#--------------task 1---------------

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn 

df = pd.read_csv("Healthcare_Hospital_Operations_Gigantic_Dataset - Healthcare_Hospital_Operations_Gigantic_Dataset.csv.csv")

show_shape = df.shape
print(show_shape)

show_first_five = df.head()
show_last_five = df.tail()

print(show_first_five)
print(show_last_five)
# Out:
# (68000, 10)
#    Patient_ID Admission_Date Hospital_Region     City  Department  \
# 0      800000     2022-01-21         Central   Mumbai     General
# 1      800001     2023-01-27           South   Mumbai     General
# 2      800002     2023-12-30             NaN  Chennai   Neurology
# 3      800003     2023-08-02             NaN  Chennai   Neurology
# 4      800004     2023-10-21           South      NaN  Pediatrics
#
#   Patient_Type  Length_of_Stay_Days  Treatment_Cost Insurance_Type  \
# 0    Inpatient                 12.0        30716.80        Private
# 1    Inpatient                  1.0       197617.22       Self-Pay
# 2    Inpatient                  8.0       403505.37        Private
# 3   Outpatient                 22.0        19975.17        Private
# 4          NaN                  NaN       434580.60     Government
#
#   Discharge_Status
# 0        Recovered
# 1         Referred
# 2        Recovered
# 3        Recovered
# 4              NaN
# ...

# %%
#--------------task 2---------------
fill = df.fillna(df)
print(fill)
delete_duplicates = df.dropna(df)
print(delete_duplicates)
# Out:
#        Patient_ID Admission_Date Hospital_Region     City  Department  \
# 0          800000     2022-01-21         Central   Mumbai     General
# 1          800001     2023-01-27           South   Mumbai     General
# 2          800002     2023-12-30             NaN  Chennai   Neurology
# 3          800003     2023-08-02             NaN  Chennai   Neurology
# 4          800004     2023-10-21           South      NaN  Pediatrics
# ...           ...            ...             ...      ...         ...
# 67995      821041     2024-05-31         Central     Pune    Oncology
# 67996      844371     2023-11-07             NaN    Delhi         NaN
# 67997      835040     2023-10-30             NaN      NaN  Cardiology
# 67998      855047     2024-03-02            East  Chennai   Neurology
# 67999      815102     2022-10-11         Central   Mumbai         NaN
#
#       Patient_Type  Length_of_Stay_Days  Treatment_Cost Insurance_Type  \
# ...

# %%
#--------------task 3---------------

# %%
#--------------task 4---------------

import matplotlib.pyplot as plt
import seaborn
plt.barplot("Department" , "patient_type" , color = 'blue')
plt.title("bar chart")
plt.xlabel("department")
plt.ylabel("patient type")
plt.show()
